# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-e1c48ad5406f> in <module>
#      10
#      11 # Incorporated citipy to determine city based on latitude and longitude
# ---> 12 from citipy import citipy
#      13
#      14 # Output File (CSV)
#
# ModuleNotFoundError: No module named 'citipy'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ec93c5f21fab> in <module>
#      10 # Identify nearest city for each lat, lng combination
#      11 for lat_lng in lat_lngs:
# ---> 12     city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
#      13
#      14     # If the city is unique, then add it to a our cities list
#
# NameError: name 'citipy' is not defined

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "imperial", "appid": api_key}
weather_df =pd.DataFrame(columns = ["City","Cloudiness", "Country",
                                    "Date", "Max Temp", "Wind Speed", 
                                    "Lat","Lng", "Humidity"])
weather_df
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Max Temp, Wind Speed, Lat, Lng, Humidity]
# Index: []

# %%
count = 1 
err = 0 
sets = 0 
index = 0 
t0 =time.time()
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1 = city.replace(" ", "%20") 
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{owm.BASE_URL}weather?q={city1}&units=imperial&APPID={api_key}')
        city_stats = owm.get_current(city, **settings)
        weather_df.set_value(index, "City", city_stats["name"])
        weather_df.set_value(index, "Cloudiness", city_stats("clouds.all"))
        weather_df.set_value(index, "Country", city_stats("sys.country"))
        weather_df.set_value(index, "Date", city_stats("dt"))
        weather_df.set_value(index, "Max Temp", city_stats("main.temp_max"))
        weather_df.set_value(index, "Wind Speed", city_stats("wind.speed"))
        weather_df.set_value(index, "Lat", city_stats("coord.lat"))
        weather_df.set_value(index, "Lng", city_stats("coord.lon"))
        weather_df.set_value(index, "Humidity", city_stats("main.humidity"))
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 51: 
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0=time.time()

print("end of stats loop")
print(f'Could not get data for {err} cities')
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | zhigansk
# name 'owm' is not defined
# Processing Record 2 of Set 0 | aksu
# name 'owm' is not defined
# Processing Record 3 of Set 0 | bredasdorp
# name 'owm' is not defined
# Processing Record 4 of Set 0 | port elizabeth
# name 'owm' is not defined
# Processing Record 5 of Set 0 | kapaa
# name 'owm' is not defined
# Processing Record 6 of Set 0 | mar del plata
# name 'owm' is not defined
# Processing Record 7 of Set 0 | busselton
# name 'owm' is not defined
# Processing Record 8 of Set 0 | taolanaro
# name 'owm' is not defined
# Processing Record 9 of Set 0 | ilulissat
# name 'owm' is not defined
# Processing Record 10 of Set 0 | chernyshevskiy
# name 'owm' is not defined
# Processing Record 11 of Set 0 | hobart
# name 'owm' is not defined
# Processing Record 12 of Set 0 | enshi
# name 'owm' is not defined
# Processing Record 13 of Set 0 | bandarbeyla
# name 'owm' is not defined
# Processing Record 14 of Set 0 | airai
# name 'owm' is not defined
# Processing Record 15 of Set 0 | belyy yar
# name 'owm' is not defined
# Processing Record 16 of Set 0 | manono
# name 'owm' is not defined
# Processing Record 17 of Set 0 | amderma
# name 'owm' is not defined
# Processing Record 18 of Set 0 | port alfred
# name 'owm' is not defined
# Processing Record 19 of Set 0 | atuona
# name 'owm' is not defined
# Processing Record 20 of Set 0 | illoqqortoormiut
# name 'owm' is not defined
# Processing Record 21 of Set 0 | paidha
# name 'owm' is not defined
# Processing Record 22 of Set 0 | nizhneyansk
# name 'owm' is not defined
# Processing Record 23 of Set 0 | bargal
# name 'owm' is not defined
# Processing Record 24 of Set 0 | plaster rock
# name 'owm' is not defined
# Processing Record 25 of Set 0 | clyde river
# name 'owm' is not defined
# Processing Record 26 of Set 0 | punta arenas
# name 'owm' is not defined
# Processing Record 27 of Set 0 | rikitea
# name 'owm' is not defined
# Processing Record 28 of Set 0 | cam ranh
# name 'owm' is not defined
# Processing Record 29 of Set 0 | palmer
# name 'owm' is not defined
# Processing Record 30 of Set 0 | vaitupu
# name 'owm' is not defined
# Processing Record 31 of Set 0 | albany
# name 'owm' is not defined
# Processing Record 32 of Set 0 | fayetteville
# name 'owm' is not defined
# Processing Record 33 of Set 0 | hilo
# name 'owm' is not defined
# Processing Record 34 of Set 0 | mataura
# name 'owm' is not defined
# Processing Record 35 of Set 0 | sambava
# name 'owm' is not defined
# Processing Record 36 of Set 0 | namibe
# name 'owm' is not defined
# Processing Record 37 of Set 0 | luganville
# name 'owm' is not defined
# Processing Record 38 of Set 0 | liverpool
# name 'owm' is not defined
# Processing Record 39 of Set 0 | lolua
# name 'owm' is not defined
# Processing Record 40 of Set 0 | kavieng
# name 'owm' is not defined
# Processing Record 41 of Set 0 | jamestown
# name 'owm' is not defined
# Processing Record 42 of Set 0 | prince rupert
# name 'owm' is not defined
# Processing Record 43 of Set 0 | srivardhan
# name 'owm' is not defined
# Processing Record 44 of Set 0 | hambantota
# name 'owm' is not defined
# Processing Record 45 of Set 0 | puerto ayora
# name 'owm' is not defined
# Processing Record 46 of Set 0 | thompson
# name 'owm' is not defined
# Processing Record 47 of Set 0 | barrow
# name 'owm' is not defined
# Processing Record 48 of Set 0 | ekibastuz
# name 'owm' is not defined
# Processing Record 49 of Set 0 | inhambane
# name 'owm' is not defined
# Processing Record 50 of Set 0 | bambanglipuro
# name 'owm' is not defined
# Processing Record 1 of Set 1 | matara
# name 'owm' is not defined
# Processing Record 2 of Set 1 | northam
# name 'owm' is not defined
# Processing Record 3 of Set 1 | provideniya
# name 'owm' is not defined
# Processing Record 4 of Set 1 | attawapiskat
# name 'owm' is not defined
# Processing Record 5 of Set 1 | zhezkazgan
# name 'owm' is not defined
# Processing Record 6 of Set 1 | fortuna
# name 'owm' is not defined
# Processing Record 7 of Set 1 | hermanus
# name 'owm' is not defined
# Processing Record 8 of Set 1 | minsk
# name 'owm' is not defined
# Processing Record 9 of Set 1 | constitucion
# name 'owm' is not defined
# Processing Record 10 of Set 1 | bokoro
# name 'owm' is not defined
# Processing Record 11 of Set 1 | leningradskiy
# name 'owm' is not defined
# Processing Record 12 of Set 1 | mys shmidta
# name 'owm' is not defined
# Processing Record 13 of Set 1 | tuktoyaktuk
# name 'owm' is not defined
# Processing Record 14 of Set 1 | sur
# name 'owm' is not defined
# Processing Record 15 of Set 1 | malakal
# name 'owm' is not defined
# Processing Record 16 of Set 1 | bluff
# name 'owm' is not defined
# Processing Record 17 of Set 1 | longyearbyen
# name 'owm' is not defined
# Processing Record 18 of Set 1 | lebu
# name 'owm' is not defined
# Processing Record 19 of Set 1 | aras
# name 'owm' is not defined
# Processing Record 20 of Set 1 | barcelos
# name 'owm' is not defined
# Processing Record 21 of Set 1 | kismayo
# name 'owm' is not defined
# Processing Record 22 of Set 1 | nidzica
# name 'owm' is not defined
# Processing Record 23 of Set 1 | mount isa
# name 'owm' is not defined
# Processing Record 24 of Set 1 | cidreira
# name 'owm' is not defined
# Processing Record 25 of Set 1 | dikson
# name 'owm' is not defined
# Processing Record 26 of Set 1 | castro
# name 'owm' is not defined
# Processing Record 27 of Set 1 | vidim
# name 'owm' is not defined
# Processing Record 28 of Set 1 | carnarvon
# name 'owm' is not defined
# Processing Record 29 of Set 1 | avarua
# name 'owm' is not defined
# Processing Record 30 of Set 1 | beira
# name 'owm' is not defined
# Processing Record 31 of Set 1 | cacheu
# name 'owm' is not defined
# Processing Record 32 of Set 1 | qaanaaq
# name 'owm' is not defined
# Processing Record 33 of Set 1 | aquiraz
# name 'owm' is not defined
# Processing Record 34 of Set 1 | opuwo
# name 'owm' is not defined
# Processing Record 35 of Set 1 | bambous virieux
# name 'owm' is not defined
# Processing Record 36 of Set 1 | cape town
# name 'owm' is not defined
# Processing Record 37 of Set 1 | saint george
# name 'owm' is not defined
# Processing Record 38 of Set 1 | solnechnyy
# name 'owm' is not defined
# Processing Record 39 of Set 1 | chase
# name 'owm' is not defined
# Processing Record 40 of Set 1 | faanui
# name 'owm' is not defined
# Processing Record 41 of Set 1 | santa maria
# name 'owm' is not defined
# Processing Record 42 of Set 1 | beringovskiy
# name 'owm' is not defined
# Processing Record 43 of Set 1 | sumenep
# name 'owm' is not defined
# Processing Record 44 of Set 1 | comodoro rivadavia
# name 'owm' is not defined
# Processing Record 45 of Set 1 | havoysund
# name 'owm' is not defined
# Processing Record 46 of Set 1 | los llanos de aridane
# name 'owm' is not defined
# Processing Record 47 of Set 1 | mayya
# name 'owm' is not defined
# Processing Record 48 of Set 1 | ushuaia
# name 'owm' is not defined
# Processing Record 49 of Set 1 | narsaq
# name 'owm' is not defined
# Processing Record 50 of Set 1 | gorontalo
# name 'owm' is not defined
# Processing Record 1 of Set 2 | gwanda
# name 'owm' is not defined
# Processing Record 2 of Set 2 | yellowknife
# name 'owm' is not defined
# Processing Record 3 of Set 2 | belushya guba
# name 'owm' is not defined
# Processing Record 4 of Set 2 | verkhnyaya sinyachikha
# name 'owm' is not defined
# Processing Record 5 of Set 2 | hachinohe
# name 'owm' is not defined
# Processing Record 6 of Set 2 | phetchaburi
# name 'owm' is not defined
# Processing Record 7 of Set 2 | quelimane
# name 'owm' is not defined
# Processing Record 8 of Set 2 | saint-philippe
# name 'owm' is not defined
# Processing Record 9 of Set 2 | sioux lookout
# name 'owm' is not defined
# Processing Record 10 of Set 2 | avera
# name 'owm' is not defined
# Processing Record 11 of Set 2 | muroto
# name 'owm' is not defined
# Processing Record 12 of Set 2 | xuanzhou
# name 'owm' is not defined
# Processing Record 13 of Set 2 | vaini
# name 'owm' is not defined
# Processing Record 14 of Set 2 | grand river south east
# name 'owm' is not defined
# Processing Record 15 of Set 2 | sola
# name 'owm' is not defined
# Processing Record 16 of Set 2 | winfield
# name 'owm' is not defined
# Processing Record 17 of Set 2 | tumannyy
# name 'owm' is not defined
# Processing Record 18 of Set 2 | sentyabrskiy
# name 'owm' is not defined
# Processing Record 19 of Set 2 | rungata
# name 'owm' is not defined
# Processing Record 20 of Set 2 | fairbanks
# name 'owm' is not defined
# Processing Record 21 of Set 2 | tuatapere
# name 'owm' is not defined
# Processing Record 22 of Set 2 | macaubas
# name 'owm' is not defined
# Processing Record 23 of Set 2 | poltavka
# name 'owm' is not defined
# Processing Record 24 of Set 2 | cabo san lucas
# name 'owm' is not defined
# Processing Record 25 of Set 2 | krasnoselkup
# name 'owm' is not defined
# Processing Record 26 of Set 2 | leirvik
# name 'owm' is not defined
# Processing Record 27 of Set 2 | boa vista
# name 'owm' is not defined
# Processing Record 28 of Set 2 | winnemucca
# name 'owm' is not defined
# Processing Record 29 of Set 2 | sangar
# name 'owm' is not defined
# Processing Record 30 of Set 2 | norman wells
# name 'owm' is not defined
# Processing Record 31 of Set 2 | naica
# name 'owm' is not defined
# Processing Record 32 of Set 2 | muisne
# name 'owm' is not defined
# Processing Record 33 of Set 2 | saleaula
# name 'owm' is not defined
# Processing Record 34 of Set 2 | egvekinot
# name 'owm' is not defined
# Processing Record 35 of Set 2 | sumbawa
# name 'owm' is not defined
# Processing Record 36 of Set 2 | ruma
# name 'owm' is not defined
# Processing Record 37 of Set 2 | chagda
# name 'owm' is not defined
# Processing Record 38 of Set 2 | jiazi
# name 'owm' is not defined
# Processing Record 39 of Set 2 | lincoln
# name 'owm' is not defined
# Processing Record 40 of Set 2 | glace bay
# name 'owm' is not defined
# Processing Record 41 of Set 2 | baykit
# name 'owm' is not defined
# Processing Record 42 of Set 2 | kahului
# name 'owm' is not defined
# Processing Record 43 of Set 2 | junin
# name 'owm' is not defined
# Processing Record 44 of Set 2 | pangnirtung
# name 'owm' is not defined
# Processing Record 45 of Set 2 | fare
# name 'owm' is not defined
# Processing Record 46 of Set 2 | santa cruz
# name 'owm' is not defined
# Processing Record 47 of Set 2 | arraial do cabo
# name 'owm' is not defined
# Processing Record 48 of Set 2 | puerto del rosario
# name 'owm' is not defined
# Processing Record 49 of Set 2 | upernavik
# name 'owm' is not defined
# Processing Record 50 of Set 2 | butaritari
# name 'owm' is not defined
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6de7cdbde715> in <module>
#      29         count = 1
#      30         sets = sets+1
# ---> 31         time.sleep(60-(t1-t0))
#      32         t0=time.time()
#      33
#
# KeyboardInterrupt:

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.count()

# %%
weather_df.to_csv("WeatherPy.csv", encoding='utf-8', index=False)


weather_df.head(10)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], color='r', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.now().date()})')
plt.savefig("LatVsTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,6))
sns.set()
plt.scatter(weather_df["Lat"], weather_df["Humidity"], color='blue', alpha=0.5)
plt.ylim(10,120)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.now().date()})')
plt.savefig("LatVsHumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], color='green', alpha=0.5)

plt.ylim(-20,(weather_df["Cloudiness"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.now().date()})')
plt.savefig("LatVsCloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
